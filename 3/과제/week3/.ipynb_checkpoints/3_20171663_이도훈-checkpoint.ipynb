# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn import datasets
from sklearn.decomposition import PCA
from IPython.display import Image

# %%
# !pip install scikit-learn

# %% [markdown]
# # iris dataset
#
# https://scikit-learn.org/stable/modules/generated/sklearn.datasets.load_iris.html

# %%
iris = datasets.load_iris()
df = pd.DataFrame(iris['data'], columns=iris['feature_names'])

# %%
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
pd.plotting.scatter_matrix(df, c=iris['target'], marker='o', s=10, alpha=.8, figsize=(12, 8))
plt.show()

# %%
X = iris.data
Y = iris.target
feature_names = iris.feature_names
target_names = iris.target_names
print(X.shape)
print(Y.shape)
# Out:
# (150, 4)
# (150,)

# %%
print(target_names)
# Out:
# ['setosa' 'versicolor' 'virginica']

# %%
df_X = pd.DataFrame(X)
df_Y = pd.DataFrame(Y)
df_Y[0].value_counts().plot(kind='bar')
plt.show()

# %%
import seaborn as sns
for i in range(df_X.shape[1]):
    sns.distplot(df_X[i])
    plt.title(feature_names[i])
    plt.show()
# Out:
# C:\Users\topia1998\Anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\topia1998\Anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %% [markdown]
# # PCA
#
# https://scikit-learn.org/stable/modules/generated/sklearn.decomposition.PCA.html

# %%
pca = PCA(n_components=2)
pca.fit(X)
PC_score = pca.transform(X)
print(PC_score[:5])
print(PC_score.shape)
# Out:
# [[-2.68412563  0.31939725]
#  [-2.71414169 -0.17700123]
#  [-2.88899057 -0.14494943]
#  [-2.74534286 -0.31829898]
#  [-2.72871654  0.32675451]]
# (150, 2)

# %%
# pca 의 eigen_vector
pca.components_
# Out:
# array([[ 0.36138659, -0.08452251,  0.85667061,  0.3582892 ],
#        [ 0.65658877,  0.73016143, -0.17337266, -0.07548102]])

# %% [markdown]
# # TODO 1
#
# 2차원 데이터가 주어졌을때 이를 scatter 하는 함수를 구현하시오.

# %%
# 아래 그림은 정답 예시
Image("show2D_sample.png")

# %%
# Hint
# plt.legend(), plt.title(), plt.scatter() 함수 이용

def show2D(pca_score, Y, target_names):
    plt.figure()
    # TODO -->
    for i, target_name in zip(range(len(target_names)), target_names):
        plt.scatter(pca_score[Y == i, 0], pca_score[Y == i, 1], label=target_name)
    plt.legend(loc = 'lower right')
    plt.title('Results', fontsize = 12)
    plt.show()
    # <--

# %%
show2D(PC_score, Y, target_names)

# %% [raw]
# # TODO 2
#
# PCA 함수를 구현하시오.
#
# ## 요구사항
# 1. normalize 한
# 2. 아래의 numpy 내장 함수 사용 가능
#     - ```numpy.mean()```
#     - ```numpy.linalg.eig()```
#     - ```numpy.dot()```

# %%
def student_pca(X, n_components=2):
    pca_results = None
    # TODO -->
    mx = np.mean(X, axis = 0)
    nX = X - mx
    iris_cov = np.cov(nX, rowvar = False)
    eig_vals,eig_vecs = np.linalg.eigh(iris_cov)
    sort = eig_vals[::-1]
    index = np.argsort(sort)
    sorted_eigvecs = eig_vecs[:,index]
    eigvecs_s = sorted_eigvecs[:,0:n_components]
    tmp = np.dot(eigvecs_s.transpose(), nX.transpose())
    pca_results = np.transpose(tmp)
    
    return pca_results

pca_student_score2 = student_pca(X, n_components=2)

# %%
show2D(pca_student_score2, Y, target_names)

# %% [markdown]
# # TODO 3
#
# digits data 를 이용하여 PCA 결과를 확인하시오.

# %%
digits = datasets.load_digits()

# %%
# TODO -->

# %%
df = pd.DataFrame(digits['data'], columns=digits['feature_names'])
X_d = digits.data
Y_d = digits.target
pca_d = student_pca(X_d,n_components=2)

# %%
show2D(pca_d, Y_d, digits.target_names)
# <--

# %%
# 예시 정답
Image('digits_sample.png')

# %% [markdown]
# # TODO 4
#
# TSNE 를 이용하여 digits 데이터의 결과를 Visualizing 하시오.

# %%
from sklearn.manifold import TSNE

# %%
tsne = TSNE(n_components=2, random_state=0)
X_t = tsne.fit_transform(X_d)

for i, digit_target_name in zip(range(len(digits.target_names)), digits.target_names):
    plt.scatter(X_t[Y_d == i, 0], X_t[Y_d == i, 1], label = digit_target_name)
plt.title('Results', fontsize=12)
plt.legend(loc='upper right')
plt.show()

# %%
# 예시 정답
Image('tsne_sample.png')

# %% [markdown]
# # 과제 : PCA Reconstruction# 과제 : PCA reconstruction
#
# Digits 데이터를 2차원, 3차원, 4차원, 32차원으로 PCA 한 결과를 reconstruction 했을 때 원래 데이터와의 MSE(Mean Square Error) 을 확인 및 복원데이터를 시각화하고 오차율이 다른 이유를 분석하여 보고서를 제출하시오. (코드, 분석내용 첨부)
#
# - 제출형식: {분반}_{학번}_{이름}.zip (ex: 1_20210928_홍길동.zip)
# - 제출파일: 보고서({분반}_{학번}_{이름}.pdf), 주피터노트북 파일({분반}_{학번}_{이름}.ipynb)
# - 제출기한: 일주일 (사이버캠퍼스 참고)

# %%
digits = datasets.load_digits()

# %%
X = digits.data
Y = digits.target
feature_names = digits.feature_names
target_names = digits.target_names
n_samples = X.shape[0]
images = X.reshape((n_samples, -1))

# %%
_, axes = plt.subplots(nrows=1, ncols=4, figsize=(10, 3))
for ax, image in zip(axes, images):
    ax.set_axis_off()
    image = image.reshape(8, 8)
    ax.imshow(image, cmap=plt.cm.gray_r, interpolation='nearest')

# %%
# 예시data:image/png;base64,...
Image('assignment_sample.png')

# %%
# TODO --> 
pca_student_score = student_pca(X, n_components = 32)

mx = np.mean(X, axis = 0)
nX = X - mx
digits_cov = np.cov(nX, rowvar = False)
eig_vals,eig_vecs = np.linalg.eigh(digits_cov)
sort = eig_vals[::-1]
index = np.argsort(sort)
sorted_eigvecs = eig_vecs[:,index]
eigvecs_s = sorted_eigvecs[:,0:32]

pca_results_t = np.transpose(pca_student_score)
tmp = np.transpose((eigvecs_s.dot(pca_results_t)))
new = tmp + mx

n_samples = new.shape[0]
images = new.reshape((n_samples,-1))

# %%
_, axes = plt.subplots(nrows=1, ncols=4, figsize=(10, 3))
for ax, image in zip(axes, images):
    ax.set_axis_off()
    image = image.reshape(8, 8)
    ax.imshow(image, cmap=plt.cm.gray_r, interpolation='nearest')
result = np.square(np.subtract(X, new)).mean()
print(result)
# Out:
# 0.6316360146108382

# %%
# TODO --> 
pca_student_score = student_pca(X, n_components=4)

mx = np.mean(X, axis = 0)
nX = X - mx
digits_cov = np.cov(nX, rowvar = False)
eig_vals,eig_vecs = np.linalg.eigh(digits_cov)
sort = eig_vals[::-1]
index = np.argsort(sort)
sorted_eigvecs = eig_vecs[:,index]
eigvecs_s = sorted_eigvecs[:,0:4]

pca_results_t = np.transpose(pca_student_score)
tmp = np.transpose((eigvecs_s.dot(pca_results_t)))
new = tmp + mx

n_samples = new.shape[0]
images = new.reshape((n_samples,-1))

# %%
_, axes = plt.subplots(nrows=1, ncols=4, figsize=(10, 3))
for ax, image in zip(axes, images):
    ax.set_axis_off()
    image = image.reshape(8, 8)
    ax.imshow(image, cmap=plt.cm.gray_r, interpolation='nearest')
result = np.square(np.subtract(X, new)).mean()
print(result)
# Out:
# 9.627986407129212

# %%
# TODO --> 
pca_student_score = student_pca(X, n_components = 3)

mx = np.mean(X, axis = 0)
nX = X - mx
digits_cov = np.cov(nX, rowvar = False)
eig_vals,eig_vecs = np.linalg.eigh(digits_cov)
sort = eig_vals[::-1]
index = np.argsort(sort)
sorted_eigvecs = eig_vecs[:,index]
eigvecs_s = sorted_eigvecs[:,0:3]

pca_results_t = np.transpose(pca_student_score)
tmp = np.transpose((eigvecs_s.dot(pca_results_t)))
new = tmp + mx

n_samples = new.shape[0]
images = new.reshape((n_samples,-1))

# %%
_, axes = plt.subplots(nrows=1, ncols=4, figsize=(10, 3))
for ax, image in zip(axes, images):
    ax.set_axis_off()
    image = image.reshape(8, 8)
    ax.imshow(image, cmap=plt.cm.gray_r, interpolation='nearest')
result = np.square(np.subtract(X, new)).mean()
print(result)
# Out:
# 11.206800697129166

# %%
# TODO --> 
pca_student_score = student_pca(X, n_components = 2)

mx = np.mean(X, axis = 0)
nX = X - mx
digits_cov = np.cov(nX, rowvar = False)
eig_vals,eig_vecs = np.linalg.eigh(digits_cov)
sort = eig_vals[::-1]
index = np.argsort(sort)
sorted_eigvecs = eig_vecs[:,index]
eigvecs_s = sorted_eigvecs[:,0:2]

pca_results_t = np.transpose(pca_student_score)
tmp = np.transpose((eigvecs_s.dot(pca_results_t)))
new = tmp + mx

n_samples = new.shape[0]
images = new.reshape((n_samples,-1))

# %%
_, axes = plt.subplots(nrows=1, ncols=4, figsize=(10, 3))
for ax, image in zip(axes, images):
    ax.set_axis_off()
    image = image.reshape(8, 8)
    ax.imshow(image, cmap=plt.cm.gray_r, interpolation='nearest')
result = np.square(np.subtract(X, new)).mean()
print(result)
# Out:
# 13.421012200761453
